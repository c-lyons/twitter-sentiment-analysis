# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from textblob import TextBlob

register_matplotlib_converters()

# %%
tweets = pd.read_csv('project-data/cleanedTweetsSentiment.csv')
tweets['created_at'] = pd.to_datetime(tweets['created_at'])  # converting created_at to datetime

# %%
i = 201
tweets.text[i]
# Out:
# 'Michael Morell the lightweight former Acting Director of CIA and a man who has made serious bad calls is a total Clinton flunky '

# %%
tweets.Polarity[i]
# Out:
# -0.20666666666666664

# %%
tweets.Subjectivity[i]
# Out:
# 0.4166666666666666

# %%
blob = TextBlob(tweets.text[i])

# %%
blob.sentiment
# Out:
# Sentiment(polarity=-0.20666666666666664, subjectivity=0.41666666666666663)

# %%
tweets[tweets.Polarity<0.9].iloc[23]['text']
# Out:
# 'Here we go with the Fake Polls Just like what happened with the Election against Crooked Hillary Clinton ABC NBC CNN they all got it wrong on purpose Suppression Polls so early They will never learn '

# %%
y = tweets.Polarity
x = tweets.created_at
plt.plot(x,y)

# %%
y = tweets.Subjectivity
x = tweets.created_at
plt.plot(x,y)
